# %% [markdown]
# ## Comparing inter-attribute logical dependencies of synthetic data generated by state-of-the art generative models with respect to the real data
# - Load real data and synthetic data generated by respective models
# - Apply Q-function on real and synthetic data to
# - Extract inter dependencies based on Q_metric values, if Q_metric for a perticular pair of features is 0 then those features are functionally dependent
# - Q_metric score tells us that there are logical dependencies in the feature pair but not specifically which combination is logically dependent or how many
# - Hence I used the previous function to extract logical dependencies based on condtional probabilities of the respective feature pair

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.stats import entropy
# %matplotlib inline
# %config InlineBackend.figure_format = 'svg'

# %%
def check_categories(data, features):
    for column in features:
        unique = np.unique(data[column])
        if len(unique) ==1:
            print('For column', column)
            print(len(unique))
    else:
        print('There are no features with same entries')

# %% [markdown]
# ## Real_data

# %%
data = pd.read_csv('merged_airbnb_reduced.csv')

# %%
data.columns
# Out:
# Index(['id', 'gender', 'age', 'signup_method', 'signup_flow', 'language',
#        'affiliate_channel', 'affiliate_provider', 'first_affiliate_tracked',
#        'signup_app', 'first_device_type', 'first_browser',
#        'country_destination', 'action', 'action_type', 'action_detail',
#        'device_type', 'secs_elapsed'],
#       dtype='object')

# %%
## Paresthesia is heavily imbalanced in real data (374,3) hence the synthetic data generated by nextconvgen and tvae generated same values for the entire column
## Nausea is heavily imbalanced in real data (376,1), hence tabddpm generated same values for the whole column, but nextconvgen and ctgan is well captured this imbalance
## Exclude such features to extract dependencies to make comparsion with differnt models

categorical_features = categorical_features = ['id','gender','signup_method','signup_flow','language','affiliate_channel','affiliate_provider','first_affiliate_tracked',
                        'signup_app', 'first_device_type', 'first_browser', 'country_destination','action_type','device_type']

# %%
check_categories(data, categorical_features)
# Out:
# There are no features with same entries

# %%
data.shape
# Out:
# (3048, 18)

# %%
len(categorical_features)
# Out:
# 14

# %%
data['country_destination'].value_counts()
# Out:
# country_destination
# 0    2105
# 1     507
# 2     172
# 6      85
# 4      74
# 5      40
# 3      30
# 9      23
# 7      12
# Name: count, dtype: int64

# %%
airbnb_FD_data = data[categorical_features] 
airbnb_FD_data.to_csv('airbnb_FD_data.csv',index=False)

# %% [markdown]
# ### If any duplicate entries in the synthetic data remove them

# %% [markdown]
# ## Synthetic_data generated by ctgan

# %%
ctgan_syn_data = pd.read_csv('synthetic_airbnb_ctgan.csv')

# %%
check_categories(ctgan_syn_data, categorical_features)
# Out:
# There are no features with same entries

# %%
airbnb_ctgan_FD_data = ctgan_syn_data[categorical_features] 
airbnb_ctgan_FD_data.to_csv('airbnb_ctgan_FD_data.csv',index=False)

# %% [markdown]
# ## Synthetic_data generated by ctabgan

# %%
ctabgan_syn_data = pd.read_csv('synthetic_airbnb_ctabgan.csv')

# %%
check_categories(ctabgan_syn_data, categorical_features)
# Out:
# There are no features with same entries

# %%
airbnb_ctabgan_FD_data = ctabgan_syn_data[categorical_features] 
airbnb_ctabgan_FD_data.to_csv('airbnb_ctabgan_FD_data.csv',index=False)

# %% [markdown]
# ## Synthetic_data generated by ctabgan plus

# %%
ctabgan_plus_syn_data = pd.read_csv('Ctabgan plus/synthetic_airbnb_ctabgan+.csv')
ctabgan_plus_syn_data = ctabgan_plus_syn_data.drop_duplicates()

# %%
check_categories(ctabgan_plus_syn_data, categorical_features)
# Out:
# There are no features with same entries

# %%
airbnb_ctabgan_plus_FD_data = ctabgan_plus_syn_data[categorical_features] 
airbnb_ctabgan_plus_FD_data.to_csv('airbnb_ctabgan_plus_FD_data.csv',index=False)

# %% [markdown]
# ## Synthetic_data generated by TVAE

# %%
tvae_syn_data = pd.read_csv('Tvae/synthetic_airbnb_tvae.csv')

# %%
check_categories(tvae_syn_data, categorical_features)
# Out:
# There are no features with same entries

# %%
airbnb_tvae_FD_data = tvae_syn_data[categorical_features] 
airbnb_tvae_FD_data.to_csv('airbnb_tvae_FD_data.csv',index=False)

# %% [markdown]
# ## Synthetic_data generated by NextConvGen

# %%
nextconvgen_syn_data = pd.read_csv('airbnb_synthetic_nextconvgen.csv')
nextconvgen_syn_data = nextconvgen_syn_data.drop_duplicates()

# %%
nextconvgen_syn_data['id'] = nextconvgen_syn_data['id'].round().astype(int)
#nextconvgen_syn_data['age'] = nextconvgen_syn_data['age'].round().astype(int)
#nextconvgen_syn_data['action'] = nextconvgen_syn_data['action'].round().astype(int)
#nextconvgen_syn_data['action_detail'] = nextconvgen_syn_data['action_detail'].round().astype(int)
#nextconvgen_syn_data['secs_elapsed'] = nextconvgen_syn_data['secs_elapsed'].round().astype(int)

# %%
nextconvgen_syn_data = nextconvgen_syn_data.rename(columns={'Target': 'country_destination'})

# %%
check_categories(nextconvgen_syn_data, categorical_features)
# Out:
# There are no features with same entries

# %%
airbnb_nextconvgen_FD_data = nextconvgen_syn_data[categorical_features] 
airbnb_nextconvgen_FD_data.to_csv('airbnb_nextconvgen_FD_data.csv',index=False)

# %% [markdown]
# ## Synthetic_data generated by Tabddpm

# %%
tabddpm_syn_data = pd.read_csv('synthetic_airbnb_tabddpm.csv')
tabddpm_syn_data['id'] = tabddpm_syn_data['id'].round().astype(int)

# %%
check_categories(tabddpm_syn_data, categorical_features)
# Out:
# There are no features with same entries

# %%
airbnb_tabddpm_FD_data = tabddpm_syn_data[categorical_features] 
airbnb_tabddpm_FD_data.to_csv('airbnb_tabddpm_FD_data.csv',index=False)

# %% [markdown]
# ## Synthetic_data generated by Tabula

# %%
tabula_syn_data = pd.read_csv('synthetic_airbnb_tabula.csv')
tabula_syn_data.duplicated().sum()
# Out:
# 1140

# %%
tabula_syn_data.shape
# Out:
# (3048, 18)

# %%
tabula_syn_data = tabula_syn_data.drop_duplicates()
tabula_syn_data['id'] = tabula_syn_data['id'].round().astype(int)

# %%
tabula_syn_data.duplicated().sum()
# Out:
# 0

# %%
data.shape
# Out:
# (3048, 18)

# %%
check_categories(tabula_syn_data, categorical_features)
# Out:
# There are no features with same entries

# %%
airbnb_tabula_FD_data = tabula_syn_data[categorical_features] 
airbnb_tabula_FD_data.to_csv('airbnb_tabula_FD_data.csv',index=False)

# %% [markdown]
# ## Q_metric calculation for real and synthetic data
# - Extract function dependencies in real and synthetic data and compare whether they are same or not
# - For each feature pair we will get Q_metric for both real and syntehtic. Take the absolute difference between each metric and add the differences
# - Lesser the difference the synthetic data is capturing the same dependencies present in the real data

# %%
def Q_metric(data, features):
    # Iterate through all pairs of features
    Q_metric = []
    functional_dependencies = []
    for feature1 in features:
        for feature2 in features:
            if feature1 != feature2:  # Avoid redundant pairs
                # Step 1: Calculate Conditional Probabilities
                conditional_probabilities = data.groupby(feature1)[feature2].value_counts(normalize=True).unstack()
                metric = (conditional_probabilities > 0).sum(axis=1) - 1
                metric = metric.sum().sum()
                if len(conditional_probabilities.columns)==1:# Avoid any feature has same entries
                    print(feature1,feature2)
                    q_metric = 0.0
                else:
                    q_metric = metric / (len(conditional_probabilities.index) * (len(conditional_probabilities.columns) - 1))
                Q_metric.append(q_metric)
                if q_metric==0:
                    fd_columns = conditional_probabilities.index,conditional_probabilities.columns
                    functional_dependencies.append(fd_columns)
                    print(f"Functional dependency: {feature1} -> {feature2}")
    if 0 not in Q_metric:
        print("There are no functional dependencies in the data.")
    if all(num == 1 for num in Q_metric):
        print("There are no logical dependencies in the data.")
    else:
        print("There are some logical dependencies in the data.")
    return Q_metric

# %% [markdown]
# ### Real data Functional dependencies and its Q_metric for all pairs of features
# - Q_metric_real variable contains the list of Q_metric scores for each pair of features
# - Snice I have 17 categorical features in my data set, the total number of feature pairs are 272 i.e (nxn)-n feature pairs

# %%
Q_metric_real = Q_metric(data, categorical_features)
# Out:
# Functional dependency: id -> gender
# Functional dependency: id -> signup_method
# Functional dependency: id -> signup_flow
# Functional dependency: id -> language
# Functional dependency: id -> affiliate_channel
# Functional dependency: id -> affiliate_provider
# Functional dependency: id -> first_affiliate_tracked
# Functional dependency: id -> signup_app
# Functional dependency: id -> first_device_type
# Functional dependency: id -> first_browser
# Functional dependency: id -> country_destination
# There are some logical dependencies in the data.

# %%
## defining colors
custom_palette = {
    0: (70/255, 114/255, 232/255),   # GoogleBlue
    1: (76/255, 150/255, 77/255),     # GoogleGreen
    2: (238/255, 179/255, 62/255)     # GoogleOrange
}

# Specify the bin edges to include values from 0.0 to 1.0
bin_edges = np.arange(0.0, 1.1, 0.1)

Q_metric_real = [round(value, 2) for value in Q_metric_real]
# Create a histogram with custom bin edges

# Set the figure size
plt.figure(figsize=(4, 4))  # Adjust width and height as needed
plt.hist(Q_metric_real, bins=bin_edges, edgecolor='black',align='mid',color=custom_palette[0],alpha=0.7)

# Add labels and title
plt.xlabel('Q-scores',fontname='DejaVu Sans', fontsize=12)
plt.ylabel('Frequency',fontname='DejaVu Sans', fontsize=12)
plt.title('Airbnb data',fontname='DejaVu Sans', fontsize=12)

# Set x-axis ticks to include values from 0.0 to 1.0
plt.xticks(bin_edges)

# Show the plot
#plt.savefig('airbnb.png', dpi=300, bbox_inches='tight')
plt.show()

# %% [markdown]
# ### CTGAN Functional dependencies and its Q_metric for all pairs of features

# %%
Q_metric_ctgan = Q_metric(ctgan_syn_data, categorical_features)
# Out:
# There are no functional dependencies in the data.
# There are some logical dependencies in the data.

# %%
def feature_pair_plot(real, synthetic):# Your two lists
    x_values = [round(value, 2) for value in real]  # Replace these values with your own list
    y_values = [round(value, 2) for value in synthetic]  # Replace these values with your own list
    # Plotting the points and drawing a curve
    plt.scatter(x_values, y_values, marker='o',color=custom_palette[2])
    plt.plot([0, 1], [0, 1], linestyle='-',color=custom_palette[0])

    # Set the same limits for both axes
    min_limit = min(min(x_values), min(y_values))
    max_limit = max(max(x_values), max(y_values))
    plt.xlim(min_limit-0.2, max_limit+0.2)
    plt.ylim(min_limit-0.2, max_limit+0.2)
    plt.gca().set_aspect('equal', adjustable='box')
    #ax = plt.gca()  #to remove the box surrounding the plot
    #ax.spines['top'].set_visible(False)
    #ax.spines['right'].set_visible(False)
    plt.xlabel('Scores of real data',fontname='DejaVu Sans', fontsize=12)
    plt.ylabel('Scores of synthetic data',fontname='DejaVu Sans', fontsize=12)
    

    # Display the plot
    #plt.savefig('tabddpm.png', dpi=300, bbox_inches='tight')
    plt.show()

# %%
def feature_pair_plot_all(real, synthetics):
    num_plots = len(synthetics)
    num_rows = 2  # Fixed number of rows for the desired layout
    num_cols = 4  # Fixed number of columns for the desired layout
    fig, axes = plt.subplots(num_rows, num_cols, figsize=(12, 6))
    model_names = ['CTGAN', 'CTABGAN', 'CTABGAN Plus', 'TVAE', 'NextConvGeN', 'TabDDPM', 'TabuLa'][:num_plots]

    # Plot real data against each synthetic data list
    for i, synthetic in enumerate(synthetics):
        row = i // num_cols  # Calculate the row index
        col = i % num_cols   # Calculate the column index
        ax = axes[row, col]  # Get the corresponding axis

        x_values = [round(value, 2) for value in real]
        y_values = [round(value, 2) for value in synthetic]
        ax.scatter(x_values, y_values, marker='o', color=custom_palette[2], label=f'Synthetic {i+1}')
        ax.plot([0, 1], [0, 1], linestyle='-', color=custom_palette[0], label='Real')
        min_limit = min(min(x_values), min(y_values))
        max_limit = max(max(x_values), max(y_values))
        ax.set_xlim(min_limit-0.2, max_limit+0.2)
        ax.set_ylim(min_limit-0.2, max_limit+0.2)
        ax.set_aspect('equal', adjustable='box')
        ax.set_xlabel('Real', fontname='DejaVu Sans', fontsize=10)
        ax.set_ylabel(f'{model_names[i]} ', fontname='DejaVu Sans', fontsize=10)
        ax.set_xticks(np.arange(-0.2, 1.3, 0.2))  # Set x-axis ticks
        ax.set_yticks(np.arange(-0.2, 1.3, 0.2))  # Set y-axis ticks
        

    # Remove any unused subplots
    for i in range(num_plots, num_rows*num_cols):
        fig.delaxes(axes.flatten()[i])
    
    plt.tight_layout(h_pad=0.5)
    plt.savefig('Airbnb_Q_metric_plot.png', dpi=700, bbox_inches='tight')    
    plt.show()

# %%
def plot_scores(real_data, synthetic_data):
    data1 = [round(value, 2) for value in real_data]
    data2 = [round(value, 2) for value in synthetic_data]

    # Creating subplots with multiple histograms
    fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(8, 4))
    bin_edges = np.arange(0.0, 1.1, 0.1)
    
    # Plot histograms
    counts1, bins1, _ = axes[0].hist(data1, bins=bin_edges, color=custom_palette[0], edgecolor='black', alpha=0.7)
    axes[0].set_title('Distribution of real scores', fontname='DejaVu Sans', fontsize=12)

    counts2, bins2, _ = axes[1].hist(data2, bins=bin_edges, color=custom_palette[1], edgecolor='black', alpha=0.7)
    axes[1].set_title('Distribution of synthetic scores', fontname='DejaVu Sans', fontsize=12)
    
    # Convert counts to probabilities
    prob1 = counts1 / len(data1)
    prob2 = (counts2 + 1e-9) / len(data2) 
    
    # Calculate KL divergence
    kl_divergence = entropy(prob1, prob2)
    print("KL Divergence score is:", kl_divergence)

    # Set y-axis limits based on the maximum frequency in both real and synthetic data
    max_freq_real = max(np.histogram(data1, bins=bins1)[0])
    max_freq_synthetic = max(np.histogram(data2, bins=bins2)[0])
    max_freq_combined = max(max_freq_real, max_freq_synthetic)

    for ax in axes:
        ax.set_ylim(0, max_freq_combined + 5)  # Adjust +1 for better visualization

    for ax in axes:
        ax.set_xlabel('Value', fontname='DejaVu Sans', fontsize=12)
        ax.set_ylabel('Frequency', fontname='DejaVu Sans', fontsize=12)
        ax.set_xticks(bin_edges)

    # Adjusting layout for better spacing
    plt.tight_layout()
    
    #plt.savefig('real_vs_tabddpm.png', dpi=300, bbox_inches='tight')

    # Display the figure
    plt.show()

# %%
plot_scores(Q_metric_real,Q_metric_ctgan)
# Out:
# KL Divergence score is: 5.586753488349505

# %%
feature_pair_plot(Q_metric_real, Q_metric_ctgan)

# %% [markdown]
# ### CTABGAN Functional dependencies and its Q_metric for all pairs of features

# %%
Q_metric_ctabgan = Q_metric(ctabgan_syn_data, categorical_features)
# Out:
# There are no functional dependencies in the data.
# There are some logical dependencies in the data.

# %%
plot_scores(Q_metric_real,Q_metric_ctabgan)
# Out:
# KL Divergence score is: 19.234215189688626

# %%
feature_pair_plot(Q_metric_real, Q_metric_ctabgan)

# %% [markdown]
# ## CTAB GAN Plus

# %%
Q_metric_ctabgan_plus = Q_metric(ctabgan_plus_syn_data, categorical_features)
# Out:
# There are no functional dependencies in the data.
# There are some logical dependencies in the data.

# %%
plot_scores(Q_metric_real,Q_metric_ctabgan_plus)
# Out:
# KL Divergence score is: 19.043165881641187

# %%
feature_pair_plot(Q_metric_real, Q_metric_ctabgan_plus)

# %% [markdown]
# ## TVAE

# %%
Q_metric_tvae = Q_metric(tvae_syn_data, categorical_features)
# Out:
# There are no functional dependencies in the data.
# There are some logical dependencies in the data.

# %%
plot_scores(Q_metric_real,Q_metric_tvae)
# Out:
# KL Divergence score is: 0.3744054967497732

# %%
feature_pair_plot(Q_metric_real, Q_metric_tvae)

# %% [markdown]
# ## NextConvGen

# %%
Q_metric_nextconvgen = Q_metric(nextconvgen_syn_data, categorical_features)
# Out:
# There are no functional dependencies in the data.
# There are some logical dependencies in the data.

# %%
plot_scores(Q_metric_real,Q_metric_nextconvgen)
# Out:
# KL Divergence score is: 1.9135849544799257

# %%
feature_pair_plot(Q_metric_real, Q_metric_nextconvgen)

# %% [markdown]
# ## TabDDPM

# %%
Q_metric_tabddpm = Q_metric(tabddpm_syn_data, categorical_features)
# Out:
# There are no functional dependencies in the data.
# There are some logical dependencies in the data.

# %% [markdown]
# nSameTabddpm = 0
# nSameNextConvGeN = 0
#
# for i, (x,y,z) in enumerate(zip(Q_metric_real, Q_metric_tabddpm, Q_metric_nextconvgen)):
#     if x == y and x != z and x < 1.0:
#         print(f"{i}: {x}  {y} {z}")
#     if x == y:
#         nSameTabddpm += 1
#
# print("---")
#
# for i, (x,y,z) in enumerate(zip(Q_metric_real, Q_metric_tabddpm, Q_metric_nextconvgen)):
#     if x <= y and x >= z and x < 1.0:
#         print(f"{i}: {x:0.2f}  {y:0.2f} {z:0.2f}")
#     if x == z:
#         nSameNextConvGeN += 1
#
# print("---")
# print(nSameTabddpm, nSameNextConvGeN)

# %%
plot_scores(Q_metric_real,Q_metric_tabddpm)
# Out:
# KL Divergence score is: 0.03917445576432303

# %%
feature_pair_plot(Q_metric_real, Q_metric_tabddpm)

# %% [markdown]
# ## TabuLa

# %%
Q_metric_tabula = Q_metric(tabula_syn_data, categorical_features)
# Out:
# Functional dependency: id -> gender
# Functional dependency: id -> signup_method
# Functional dependency: id -> signup_flow
# Functional dependency: id -> language
# Functional dependency: id -> affiliate_channel
# Functional dependency: id -> affiliate_provider
# Functional dependency: id -> first_affiliate_tracked
# Functional dependency: id -> signup_app
# Functional dependency: id -> first_device_type
# Functional dependency: id -> first_browser
# Functional dependency: id -> country_destination
# There are some logical dependencies in the data.

# %%
plot_scores(Q_metric_real,Q_metric_tabula)
# Out:
# KL Divergence score is: 0.015394065865073287

# %%
feature_pair_plot(Q_metric_real, Q_metric_tabula)

# %%
synthetic_data_lists = [Q_metric_ctgan, Q_metric_ctabgan, Q_metric_ctabgan_plus, Q_metric_tvae, Q_metric_nextconvgen, Q_metric_tabddpm,Q_metric_tabula]
feature_pair_plot_all(Q_metric_real, synthetic_data_lists)

# %% [markdown]
# ## Comparing logical dependencies of real and synthetic data (only for 0 and 1 probabilities)

# %%
def common_dependencies(real_data,synthetic_data, features):
    # Lists to store combinations with conditional probabilities of 0 and 1
    common_zero_probabilities = []
    common_one_probabilities = []
    ground_truth = []
    count=0
    match=0
    
    

    # Iterate through all pairs of features
    for feature1 in features:
        for feature2 in features:
            if feature1 != feature2:  # Avoid redundant pairs
                # Step 1: Calculate Conditional Probabilities
                conditional_probabilities_real = real_data.groupby(feature1)[feature2].value_counts(normalize=True).unstack()
                conditional_probabilities_synthetic = synthetic_data.groupby(feature1)[feature2].value_counts(normalize=True).unstack()
                                

                # Identify rows with any value exactly equal to 1
                #rows_with_one_real = conditional_probabilities_real.index[conditional_probabilities_real.eq(1).any(axis=1)]
                #rows_with_one_synthetic = conditional_probabilities_synthetic.index[conditional_probabilities_synthetic.eq(1).any(axis=1)]
                

                # Fill NaN values with 0 in rows with any value equal to 1
                conditional_probabilities_real = conditional_probabilities_real.fillna(0)
                conditional_probabilities_synthetic = conditional_probabilities_synthetic.fillna(0)
                
                
                # Step 2: Check for 0 or 1 probabilities and store in lists
                for level1 in conditional_probabilities_real.index:
                    for level2 in conditional_probabilities_real.columns:
                        dummy=None
                        if level1 not in conditional_probabilities_synthetic.index or level2 not in conditional_probabilities_synthetic.columns:
                            dummy=np.float64(0.5)
                            
                        probability_real = conditional_probabilities_real.loc[level1, level2]
                        probability_synthetic = conditional_probabilities_synthetic.loc[level1, level2] if dummy is None else dummy
                        
                        if probability_real==0:
                            count+=1
                            ground_truth.append((feature1, level1, feature2, level2,probability_real))
                            if probability_synthetic==0:
                                common_zero_probabilities.append((feature1, level1, feature2, level2,probability_real,probability_synthetic))
                                match+=1
                            else:
                                pass
                        elif probability_real==1:
                            count+=1
                            ground_truth.append((feature1, level1, feature2, level2,probability_real))
                            if probability_synthetic==1:
                                common_one_probabilities.append((feature1, level1, feature2, level2,probability_real,probability_synthetic))
                                match+=1
                            else:
                                pass
                                
    # Create DataFrames
    df_zero = pd.DataFrame(common_zero_probabilities, columns=['Feature1', 'Level1', 'Feature2', 'Level2', 'Probability_real','Probability_synthetic'])
    df_one = pd.DataFrame(common_one_probabilities, columns=['Feature1', 'Level1', 'Feature2', 'Level2', 'Probability_real','Probability_synthetic'])
    real_dependencies = pd.DataFrame(ground_truth, columns=['Feature1', 'Level1', 'Feature2', 'Level2', 'Probability'])
    
    print('Total number of logical dependencies in real data are:', count)
    print('Total number of logical dependencies in synthetic data data are:', match)
    print('The pecentange of dependencies preserved in synthetic data is :',(match/count)*100)
    return df_zero, df_one, real_dependencies,count,match

# %% [markdown]
# ### CTGAN

# %%
df_zero_ctgan, df_one_ctgan, real_dependencies, total_count, ctgan_match = common_dependencies(data,ctgan_syn_data, categorical_features)
# Out:
# Total number of logical dependencies in real data are: 24369
# Total number of logical dependencies in synthetic data data are: 8500
# The pecentange of dependencies preserved in synthetic data is : 34.880380811686976

# %%
df_one_ctgan.shape
# Out:
# (46, 6)

# %%
real_dependencies[real_dependencies['Probability']==1.0]
# Out:
#           Feature1  Level1             Feature2  Level2  Probability
# 0               id       0               gender       0          1.0
# 5               id       1               gender       3          1.0
# 6               id       2               gender       0          1.0
# 10              id       3               gender       1          1.0
# 12              id       4               gender       0          1.0
# ...            ...     ...                  ...     ...          ...
# 24280  device_type       7        first_browser       4          1.0
# 24322  device_type       7  country_destination       0          1.0
# 24331  device_type       8  country_destination       0          1.0
# 24345  device_type       4          action_type       4          1.0
# 24357  device_type       6          action_type       4          1.0
#
# [2091 rows x 5 columns]

# %% [markdown]
# ## CTABGAN

# %%
df_zero_ctabgan, df_one_ctabgan, real_dependencies, total_count, ctabgan_match = common_dependencies(data,ctabgan_syn_data, categorical_features)
# Out:
# Total number of logical dependencies in real data are: 24369
# Total number of logical dependencies in synthetic data data are: 166
# The pecentange of dependencies preserved in synthetic data is : 0.681193319381181

# %% [markdown]
# ## CTAB GAN Plus

# %%
df_zero_ctabgan_plus, df_one_ctabgan_plus, real_dependencies, total_count, ctabgan_plus_match = common_dependencies(data,ctabgan_plus_syn_data, categorical_features)
# Out:
# Total number of logical dependencies in real data are: 24369
# Total number of logical dependencies in synthetic data data are: 583
# The pecentange of dependencies preserved in synthetic data is : 2.3923837662604126

# %% [markdown]
# ## TVAE

# %%
df_zero_tvae, df_one_tvae, real_dependencies, total_count, tvae_match = common_dependencies(data,tvae_syn_data, categorical_features)
# Out:
# Total number of logical dependencies in real data are: 24369
# Total number of logical dependencies in synthetic data data are: 13840
# The pecentange of dependencies preserved in synthetic data is : 56.79346710985268

# %% [markdown]
# ## NextConvGen

# %%
df_zero_nextconvgen, df_one_nextconvgen, real_dependencies, total_count, nextconvgen_match = common_dependencies(data,nextconvgen_syn_data, categorical_features)
# Out:
# Total number of logical dependencies in real data are: 24369
# Total number of logical dependencies in synthetic data data are: 15442
# The pecentange of dependencies preserved in synthetic data is : 63.367392999302396

# %%
df_one_nextconvgen.shape
# Out:
# (540, 6)

# %% [markdown]
# ## Tabddpm

# %%
df_zero_tabddpm, df_one_tabddpm, real_dependencies, total_count, tabddpm_match = common_dependencies(data,tabddpm_syn_data, categorical_features)
# Out:
# Total number of logical dependencies in real data are: 24369
# Total number of logical dependencies in synthetic data data are: 20133
# The pecentange of dependencies preserved in synthetic data is : 82.61725963314046

# %%
df_one_tabddpm.shape
# Out:
# (1067, 6)

# %% [markdown]
# ## TabuLa

# %%
df_zero_tabula, df_one_tabula, real_dependencies, total_count, tabula_match = common_dependencies(data,tabula_syn_data, categorical_features)
# Out:
# Total number of logical dependencies in real data are: 24369
# Total number of logical dependencies in synthetic data data are: 24211
# The pecentange of dependencies preserved in synthetic data is : 99.35163527432394

# %% [markdown]
# ## Comparing logical dependencies of real and synthetic data (for >0.9 and <0.1 probabilities with 0.1 threshold in synthetic data)

# %%
def LD_comparision(total_count,ctgan_match, ctabgan_match, ctabgan_plus_match, tvae_match, nextconvgen_match, tabddpm_match):
    real_data_dependencies = total_count  # Total number of logical dependencies in real data
    synthetic_data_dependencies = [ctgan_match, ctabgan_match, ctabgan_plus_match, tvae_match, nextconvgen_match, tabddpm_match]  # Total number of logical dependencies preserved by each generative model

    # Calculate the percentage of logical dependencies preserved by each model
    percentage_preserved = [(count / real_data_dependencies) * 100 for count in synthetic_data_dependencies]

    # Generative model names
    model_names = ['CTGAN', 'CTABGAN', 'CTABGAN Plus', 'TVAE', 'NextConvGen', 'Tabddpm']

    # Plotting the bar plot
    plt.figure(figsize=(8, 4))
    plt.bar(model_names, percentage_preserved, color=custom_palette[2],width=0.3)
    #plt.xlabel('Generative Models',fontname='DejaVu Sans', fontsize=12)
    plt.ylabel('Preserved dependencies (%)',fontname='DejaVu Sans', fontsize=12)
    plt.title('Airbnb data',fontname='DejaVu Sans', fontsize=12)
    plt.ylim(0, 100+10)  # Set the y-axis limit to 0-100%

    # Displaying the percentages on top of the bars
    for i, percentage in enumerate(percentage_preserved):
        plt.text(i, percentage + 1, f'{percentage:.2f}%', ha='center', va='bottom')

    # Show the plot
    #plt.savefig('Airbnb_LD_comparsion.png', dpi=700, bbox_inches='tight')
    plt.show()

# %%
LD_comparision(total_count,ctgan_match, ctabgan_match, ctabgan_plus_match, tvae_match, nextconvgen_match, tabddpm_match)

# %%
def common_dependencies_with_threshold(real_data,synthetic_data, features, high, low, t):
    # Lists to store combinations with conditional probabilities of 0 and 1
    common_zero_probabilities = []
    common_one_probabilities = []
    ground_truth = []
    count=0
    match=0
    
    

    # Iterate through all pairs of features
    for feature1 in features:
        for feature2 in features:
            if feature1 != feature2:  # Avoid redundant pairs
                # Step 1: Calculate Conditional Probabilities
                conditional_probabilities_real = real_data.groupby(feature1)[feature2].value_counts(normalize=True).unstack()
                conditional_probabilities_synthetic = synthetic_data.groupby(feature1)[feature2].value_counts(normalize=True).unstack()
                
                #print(conditional_probabilities)

                # Identify rows with any value exactly equal to 1
                #rows_with_one_real = conditional_probabilities_real.index[conditional_probabilities_real.eq(1).any(axis=1)]
                #rows_with_one_synthetic = conditional_probabilities_synthetic.index[conditional_probabilities_synthetic.eq(1).any(axis=1)]
                

                # Fill NaN values with 0 in rows with any value equal to 1
                conditional_probabilities_real = conditional_probabilities_real.fillna(0)
                conditional_probabilities_synthetic = conditional_probabilities_synthetic.fillna(0)
                
                #print(conditional_probabilities_real.index, conditional_probabilities_real.columns )
                #print(conditional_probabilities_synthetic.index, conditional_probabilities_synthetic.columns )

                # Step 2: Check for 0 or 1 probabilities and store in lists
                for level1 in conditional_probabilities_real.index:
                    for level2 in conditional_probabilities_real.columns:
                        dummy=None
                        #print(level1, level2)
                        #print(conditional_probabilities_synthetic.index,conditional_probabilities_synthetic.columns )
                        if level1 not in conditional_probabilities_synthetic.index or level2 not in conditional_probabilities_synthetic.columns:
                            dummy=np.float64(0.5)
                            
                        probability_real = conditional_probabilities_real.loc[level1, level2]
                        probability_synthetic = conditional_probabilities_synthetic.loc[level1, level2] if dummy is None else dummy
                        
                        if probability_real<low:
                            count+=1
                            ground_truth.append((feature1, level1, feature2, level2,probability_real))
                            if probability_synthetic<low+t:
                                common_zero_probabilities.append((feature1, level1, feature2, level2,probability_real,probability_synthetic))
                                match+=1
                            else:
                                pass
                        elif probability_real>high:
                            count+=1
                            ground_truth.append((feature1, level1, feature2, level2,probability_real))
                            if probability_synthetic>high-t:
                                common_one_probabilities.append((feature1, level1, feature2, level2,probability_real,probability_synthetic))
                                match+=1
                            else:
                                pass
                                
    # Create DataFrames
    df_zero = pd.DataFrame(common_zero_probabilities, columns=['Feature1', 'Level1', 'Feature2', 'Level2', 'Probability_real','Probability_synthetic'])
    df_one = pd.DataFrame(common_one_probabilities, columns=['Feature1', 'Level1', 'Feature2', 'Level2', 'Probability_real','Probability_synthetic'])
    real_dependencies = pd.DataFrame(ground_truth, columns=['Feature1', 'Level1', 'Feature2', 'Level2', 'Probability'])
    
    print('Total number of logical dependencies in real data are:', count)
    print('Total number of logical dependencies in synthetic data data are:', match)
    print('The pecentange of dependencies preserved in synthetic data is :',(match/count)*100)
    return df_zero, df_one, real_dependencies, count,match

# %% [markdown]
# ### CTGAN

# %%
df_zero_ctgan, df_one_ctgan, real_dependencies, total_count, ctgan_match = common_dependencies_with_threshold(data,ctgan_syn_data, categorical_features, 0.9,0.1,0.1)
# Out:
# Total number of logical dependencies in real data are: 28281
# Total number of logical dependencies in synthetic data data are: 24551
# The pecentange of dependencies preserved in synthetic data is : 86.81093313532054

# %% [markdown]
# ## CTABGAN

# %%
df_zero_ctabgan, df_one_ctabgan, real_dependencies, total_count, ctabgan_match = common_dependencies_with_threshold(data,ctabgan_syn_data, categorical_features,0.9,0.1,0.1)
# Out:
# Total number of logical dependencies in real data are: 28281
# Total number of logical dependencies in synthetic data data are: 4371
# The pecentange of dependencies preserved in synthetic data is : 15.455606237403204

# %% [markdown]
# ## CTAB GAN Plus

# %%
df_zero_ctabgan_plus, df_one_ctabgan_plus, real_dependencies, total_count, ctabgan_plus_match = common_dependencies_with_threshold(data,ctabgan_plus_syn_data, categorical_features,0.9,0.1,0.1)
# Out:
# Total number of logical dependencies in real data are: 28281
# Total number of logical dependencies in synthetic data data are: 5528
# The pecentange of dependencies preserved in synthetic data is : 19.54669212545525

# %% [markdown]
# ## TVAE

# %%
df_zero_tvae, df_one_tvae, real_dependencies, total_count, tvae_match = common_dependencies_with_threshold(data,tvae_syn_data, categorical_features,0.9,0.1,0.1)
# Out:
# Total number of logical dependencies in real data are: 28281
# Total number of logical dependencies in synthetic data data are: 24721
# The pecentange of dependencies preserved in synthetic data is : 87.41204342137831

# %% [markdown]
# ## NextConvGen

# %%
df_zero_nextconvgen, df_one_nextconvgen, real_dependencies, total_count, nextconvgen_match = common_dependencies_with_threshold(data,nextconvgen_syn_data, categorical_features,0.9,0.1,0.1)
# Out:
# Total number of logical dependencies in real data are: 28281
# Total number of logical dependencies in synthetic data data are: 24600
# The pecentange of dependencies preserved in synthetic data is : 86.98419433541955

# %% [markdown]
# ## Tabddpm

# %%
df_zero_tabddpm, df_one_tabddpm, real_dependencies, total_count, tabddpm_match = common_dependencies_with_threshold(data,tabddpm_syn_data, categorical_features,0.9,0.1,0.1)
# Out:
# Total number of logical dependencies in real data are: 28281
# Total number of logical dependencies in synthetic data data are: 26780
# The pecentange of dependencies preserved in synthetic data is : 94.69254976839574

# %%
LD_comparision(total_count,ctgan_match, ctabgan_match, ctabgan_plus_match, tvae_match, nextconvgen_match, tabddpm_match)
